# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import country_converter as coco
import seaborn as sns

pd.set_option("max_columns", None)

# %%
cc = coco.CountryConverter()

# %%
covid_df = pd.read_csv("data/covid.csv")
covid_df = covid_df[['Country/Region', 'Lat', 'Long', '5/25/20']]

#drop cruise ships
covid_df = covid_df.drop(48).drop(104)

#add country code column
countries = covid_df['Country/Region'].tolist()
standard_countries = cc.convert(names=countries, to='ISO3')
covid_df['Country Code'] = standard_countries

covid_df = covid_df.rename(columns={'5/25/20': 'COVID-19 Cases', 'Country/Region': 'Country'})

covid_df = covid_df[['Country', 'Country Code',  'Lat', 'Long', 'COVID-19 Cases']]

# %%
#clean and merge malaria data

malaria_df = pd.read_csv('data/Malaria_WHO.csv')
malaria_df = malaria_df.rename(columns={"Country":"country", "Estimated number of malaria cases":"Malaria Cases"})

countries = malaria_df['country'].tolist()
standard_countries = cc.convert(names=countries, to='ISO3')
malaria_df['Country Code'] = standard_countries

malaria_df = malaria_df.drop(['country'], axis=1)

df = pd.merge(covid_df, malaria_df, how='left', on='Country Code')

# %%
#clean and merge human development index data

hdi_df = pd.read_csv('data/hdi.csv', thousands=',')
countries = hdi_df['Country'].tolist()
standard_countries = cc.convert(names=countries, to='ISO3')

hdi_df['Country Code'] = standard_countries

hdi_df = hdi_df.drop('Country', axis=1)

df = pd.merge(df, hdi_df, how='left', on='Country Code')

# %%
#clean and merge world happiness index data

whi_df = pd.read_csv('data/whi.csv')

countries = whi_df['Country name'].tolist()
standard_countries = cc.convert(names=countries, to='ISO3')
whi_df['Country Code'] = standard_countries

whi_df = whi_df.groupby('Country name', as_index=False).nth(-1)
whi_df = whi_df.drop(['Year', 'Country name'], axis=1)

df = pd.merge(df, whi_df, how='left', on='Country Code')

# %%
#clean and merge air travel data

air_df = pd.read_csv('data/air.csv')
air_df = air_df[['Country Code', '2018']]
air_df = air_df.rename(columns={'2018': 'Air Passengers Carried'})

df = pd.merge(df, air_df, how='left', on='Country Code')

# %%
#clean and merge testing data

test_df = pd.read_csv('data/tests.csv')
test_df = test_df.iloc[0:230]

countries = test_df['Country'].tolist()
standard_countries = cc.convert(names=countries, to='ISO3')
test_df['Country Code'] = standard_countries

test_df = test_df[['Country Code', 'Tested', 'Positive', 'Positive/Tested %']]

test_df = test_df.rename(columns={'Tested': 'Tests Conducted', 'Positive': 'Positive Tests'})

df = pd.merge(df, test_df, how='left', on='Country Code')

# %%
#clean and merge hospital bed data

beds_df = pd.read_csv('data/hospital_beds.csv', thousands=',')

countries = beds_df['Country/territory'].tolist()
standard_countries = cc.convert(names=countries, to='ISO3')
beds_df['Country Code'] = standard_countries

beds_df = beds_df[['Country Code', 'hosp_beds_per_1000_2017', 'Occupancy_percent']]
beds_df = beds_df.rename(columns={'hosp_beds_per_1000_2017': 'Hospital Beds/1000', 'Occupancy_percent': 'Occupancy%'})
beds_df.dtypes

df = pd.merge(df, beds_df, how='left', on='Country Code')
# Out:
# WARNING:root: Ireland not found in regex

# %%
#clean and merge population data

pop_df = pd.read_csv('data/population.csv', thousands=',', na_values='N.A.')

countries = pop_df['Country'].tolist()
standard_countries = cc.convert(names=countries, to='ISO3')
pop_df['Country Code'] = standard_countries

pop_df = pop_df[['Country Code', 'Population_2020', 'Density_KM2m', 'Migrants', 'Fertility_rate', 'Median_age', 'Urban_pop_pct']]

pop_df.columns = ['Country Code', 'Population', 'Population Density', 'Migrants', 'Fertility Rate', 'Median Age', 'Urban Population%']

pop_df['Urban Population%'] = pop_df['Urban Population%'].str.rstrip('%').astype('float') / 100.0

df = pd.merge(df, pop_df, how='left', on='Country Code')
# Out:
# WARNING:root:Channel Islands not found in regex

# %%
#clean and merge quality of life index data

qol_df = pd.read_csv('data/qol.csv')

countries = qol_df['Country'].tolist()
standard_countries = cc.convert(names=countries, to='ISO3')
qol_df['Country Code'] = standard_countries

qol_df = qol_df.drop(['Rank', 'Country'], axis=1)

df = pd.merge(df, qol_df, how='left', on='Country Code')

# %%
#clean and merge country weather data

weather_df = pd.read_csv('data/weather.csv')
weather_df = weather_df.groupby('Country/Region', as_index=False).mean()

weather_df = weather_df[['Country/Region', 'temp', 'min', 'max', 'stp', 'wdsp', 'prcp', 'fog']]

countries = weather_df['Country/Region'].tolist()
standard_countries = cc.convert(names=countries, to='ISO3')
weather_df['Country Code'] = standard_countries

weather_df = weather_df.drop(['Country/Region'], axis=1)

weather_df.columns = ['Avg Temp', 'Min Temp', 'Max Temp', 'Avg Pressure', 'Wind Speed', 'Precipitation', 'Fog', 'Country Code']

df = pd.merge(df, weather_df, how='left', on='Country Code')
# Out:
# WARNING:root:Cruise Ship not found in regex

# %%
#drop duplicates
df = df.drop_duplicates('Country Code')
df
# Out:
#                 Country Country Code        Lat       Long  COVID-19 Cases  \
# 0           Afghanistan          AFG  33.000000  65.000000           11173
# 1               Albania          ALB  41.153300  20.168300            1004
# 3               Algeria          DZA  28.033900   1.659600            8503
# 4               Andorra          AND  42.506300   1.521800             763
# 5                Angola          AGO -11.202700  17.873900              70
# ..                  ...          ...        ...        ...             ...
# 301  West Bank and Gaza          PSE  31.952200  35.233200             423
# 303      Western Sahara          ESH  24.215500 -12.885800               9
# 304               Yemen          YEM  15.552727  48.516388             233
# 305              Zambia          ZMB -15.416700  28.283300             920
# 306            Zimbabwe          ZWE -20.000000  30.000000              56
#
#      Malaria Cases  Human development index (HDI) 2018  \
# 0         630308.0                               0.496
# 1              NaN                               0.791
# 3              0.0                               0.759
# 4              NaN                               0.857
# 5        4615605.0                               0.574
# ..             ...                                 ...
# 301            NaN                               0.690
# 303            NaN                                 NaN
# 304       762995.0                               0.463
# 305      3475522.0                               0.591
# 306      1239430.0                               0.563
#
#      Life expectancy at birth 2018  Expected years of schooling 2018  \
# 0                             64.5                              10.1
# 1                             78.5                              15.2
# 3                             76.7                              14.7
# 4                             81.8                              13.3
# 5                             60.8                              11.8
# ..                             ...                               ...
# 301                           73.9                              12.8
# 303                            NaN                               NaN
# 304                           66.1                               8.7
# 305                           63.5                              12.1
# 306                           61.2                              10.5
#
#      Mean years of schooling 2018  \
# 0                             3.9
# 1                            10.1
# 3                             8.0
# 4                            10.2
# 5                             5.1
# ..                            ...
# 301                           9.1
# 303                           NaN
# 304                           3.2
# 305                           7.1
# 306                           8.3
#
#      Gross national income (GNI) per capita 2018  Life Ladder  \
# 0                                         1746.0     2.694303
# 1                                        12300.0     5.004403
# 3                                        13639.0     5.043086
# 4                                        48641.0          NaN
# 5                                         5555.0     3.794838
# ..                                           ...          ...
# 301                                       5314.0     4.553922
# 303                                          NaN          NaN
# 304                                       1433.0     3.057514
# 305                                       3582.0     4.041488
# 306                                       2661.0     3.616480
#
#      Log GDP per capita  Social support  Healthy life expectancy at birth  \
# 0              7.494588        0.507516                         52.599998
# 1              9.412399        0.683592                         68.699997
# 3              9.557952        0.798651                         65.900002
# 4                   NaN             NaN                               NaN
# 5              8.741481        0.754615                         54.599998
# ..                  ...             ...                               ...
# 301                 NaN        0.819479                               NaN
# 303                 NaN             NaN                               NaN
# 304                 NaN        0.789422                         56.700001
# 305            8.223958        0.717720                         55.299999
# 306            7.553395        0.775388                         55.599998
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                        0.373536   -0.084888                   0.927606
# 1                        0.824212    0.005385                   0.899129
# 3                        0.583381   -0.172413                   0.758704
# 4                             NaN         NaN                        NaN
# 5                        0.374542   -0.157062                   0.834076
# ..                            ...         ...                        ...
# 301                      0.654535         NaN                   0.813780
# 303                           NaN         NaN                        NaN
# 304                      0.552726         NaN                   0.792587
# 305                      0.790626    0.036644                   0.810731
# 306                      0.762675   -0.038384                   0.844209
#
#      Positive affect  Negative affect  Confidence in national government  \
# 0           0.424125         0.404904                           0.364666
# 1           0.713300         0.318997                           0.435338
# 3           0.591043         0.292946                                NaN
# 4                NaN              NaN                                NaN
# 5           0.578517         0.367864                           0.572346
# ..               ...              ...                                ...
# 301         0.610405         0.418929                           0.392373
# 303              NaN              NaN                                NaN
# 304         0.461114         0.314870                           0.308151
# 305         0.702698         0.350963                           0.606715
# 306         0.710119         0.211726                           0.550508
#
#      Democratic Quality  Delivery Quality  \
# 0                   NaN               NaN
# 1                   NaN               NaN
# 3                   NaN               NaN
# 4                   NaN               NaN
# 5             -0.739363         -1.168539
# ..                  ...               ...
# 301                 NaN               NaN
# 303                 NaN               NaN
# 304                 NaN               NaN
# 305                 NaN               NaN
# 306                 NaN               NaN
#
#      Standard deviation of ladder by country-year  \
# 0                                        1.408344
# 1                                        2.640531
# 3                                        1.973943
# 4                                             NaN
# 5                                        2.196711
# ..                                            ...
# 301                                      2.580389
# 303                                           NaN
# 304                                      2.402008
# 305                                      2.783419
# 306                                      2.498696
#
#      Standard deviation/Mean of ladder by country-year  \
# 0                                             0.522712
# 1                                             0.527642
# 3                                             0.391416
# 4                                                  NaN
# 5                                             0.578868
# ..                                                 ...
# 301                                           0.566630
# 303                                                NaN
# 304                                           0.785608
# 305                                           0.688711
# 306                                           0.690919
#
#      GINI index (World Bank estimate)  \
# 0                                 NaN
# 1                                 NaN
# 3                                 NaN
# 4                                 NaN
# 5                                 NaN
# ..                                ...
# 301                               NaN
# 303                               NaN
# 304                               NaN
# 305                               NaN
# 306                               NaN
#
#      GINI index (World Bank estimate), average 2000-16  \
# 0                                                  NaN
# 1                                              0.30325
# 3                                              0.27600
# 4                                                  NaN
# 5                                              0.47350
# ..                                                 ...
# 301                                                NaN
# 303                                                NaN
# 304                                            0.35700
# 305                                            0.52740
# 306                                            0.43200
#
#      gini of household income reported in Gallup, by wp5-year  \
# 0                                             0.290681
# 1                                             0.456174
# 3                                             0.667872
# 4                                                  NaN
# 5                                             0.440699
# ..                                                 ...
# 301                                           0.482421
# 303                                                NaN
# 304                                           0.448597
# 305                                           0.619443
# 306                                           0.541772
#
#      Most people can be trusted, Gallup  \
# 0                                   NaN
# 1                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# ..                                  ...
# 301                                 NaN
# 303                                 NaN
# 304                                 NaN
# 305                                 NaN
# 306                                 NaN
#
#      Most people can be trusted, WVS round 1981-1984  \
# 0                                                NaN
# 1                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# ..                                               ...
# 301                                              NaN
# 303                                              NaN
# 304                                              NaN
# 305                                              NaN
# 306                                              NaN
#
#      Most people can be trusted, WVS round 1989-1993  \
# 0                                                NaN
# 1                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# ..                                               ...
# 301                                              NaN
# 303                                              NaN
# 304                                              NaN
# 305                                              NaN
# 306                                              NaN
#
#      Most people can be trusted, WVS round 1994-1998  \
# 0                                                NaN
# 1                                           0.243243
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# ..                                               ...
# 301                                              NaN
# 303                                              NaN
# 304                                              NaN
# 305                                              NaN
# 306                                              NaN
#
#      Most people can be trusted, WVS round 1999-2004  \
# 0                                                NaN
# 1                                           0.232000
# 3                                           0.107644
# 4                                                NaN
# 5                                                NaN
# ..                                               ...
# 301                                              NaN
# 303                                              NaN
# 304                                              NaN
# 305                                              NaN
# 306                                         0.116683
#
#      Most people can be trusted, WVS round 2005-2009  \
# 0                                                NaN
# 1                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# ..                                               ...
# 301                                              NaN
# 303                                              NaN
# 304                                              NaN
# 305                                         0.110429
# 306                                              NaN
#
#      Most people can be trusted, WVS round 2010-2014  Air Passengers Carried  \
# 0                                                NaN              1722612.61
# 1                                                NaN               303137.00
# 3                                           0.179286              6442442.00
# 4                                                NaN                     NaN
# 5                                                NaN              1516628.00
# ..                                               ...                     ...
# 301                                         0.158000                     NaN
# 303                                              NaN                     NaN
# 304                                         0.385000               336310.00
# 305                                              NaN                 8904.00
# 306                                         0.082942               282539.00
#
#      Tests Conducted  Positive Tests  Positive/Tested %  Hospital Beds/1000  \
# 0                NaN             NaN                NaN                 NaN
# 1            12024.0           946.0               7.90                 NaN
# 3                NaN             NaN                NaN                 NaN
# 4                NaN             NaN                NaN                 NaN
# 5                NaN             NaN                NaN                 NaN
# ..               ...             ...                ...                 ...
# 301          34511.0           547.0               1.60                 NaN
# 303              NaN             NaN                NaN                 NaN
# 304              NaN             NaN                NaN                 NaN
# 305              NaN             NaN                NaN                 NaN
# 306           8244.0            34.0               0.41                 NaN
#
#      Occupancy%  Population  Population Density  Migrants  Fertility Rate  \
# 0           NaN  38928346.0                60.0  -62920.0             4.6
# 1           NaN   2877797.0               105.0  -14000.0             1.6
# 3           NaN  43851044.0                18.0  -10000.0             3.1
# 4           NaN     77265.0               164.0       NaN             NaN
# 5           NaN  32866272.0                26.0    6413.0             5.6
# ..          ...         ...                 ...       ...             ...
# 301         NaN   5101414.0               847.0  -10563.0             3.7
# 303         NaN    597339.0                 2.0    5582.0             2.4
# 304         NaN  29825964.0                56.0  -30000.0             3.8
# 305         NaN  18383955.0                25.0   -8000.0             4.7
# 306         NaN  14862924.0                38.0 -116858.0             3.6
#
#      Median Age  Urban Population%  Quality of Life Index  \
# 0          18.0               0.25                    NaN
# 1          36.0               0.63                    NaN
# 3          29.0               0.73                    NaN
# 4           NaN               0.88                    NaN
# 5          17.0               0.67                    NaN
# ..          ...                ...                    ...
# 301        21.0               0.80                    NaN
# 303        28.0               0.87                    NaN
# 304        20.0               0.38                    NaN
# 305        18.0               0.45                    NaN
# 306        19.0               0.38                    NaN
#
#      Purchasing Power Index  Safety Index  Health Care Index  \
# 0                       NaN           NaN                NaN
# 1                       NaN           NaN                NaN
# 3                       NaN           NaN                NaN
# 4                       NaN           NaN                NaN
# 5                       NaN           NaN                NaN
# ..                      ...           ...                ...
# 301                     NaN           NaN                NaN
# 303                     NaN           NaN                NaN
# 304                     NaN           NaN                NaN
# 305                     NaN           NaN                NaN
# 306                     NaN           NaN                NaN
#
#      Cost of Living Index  Property Price to Income Ratio  \
# 0                     NaN                             NaN
# 1                     NaN                             NaN
# 3                     NaN                             NaN
# 4                     NaN                             NaN
# 5                     NaN                             NaN
# ..                    ...                             ...
# 301                   NaN                             NaN
# 303                   NaN                             NaN
# 304                   NaN                             NaN
# 305                   NaN                             NaN
# 306                   NaN                             NaN
#
#      Traffic Commute Time Index  Pollution Index  Climate Index   Avg Temp  \
# 0                           NaN              NaN            NaN  33.693443
# 1                           NaN              NaN            NaN  52.313115
# 3                           NaN              NaN            NaN  69.324590
# 4                           NaN              NaN            NaN  34.662295
# 5                           NaN              NaN            NaN        NaN
# ..                          ...              ...            ...        ...
# 301                         NaN              NaN            NaN        NaN
# 303                         NaN              NaN            NaN        NaN
# 304                         NaN              NaN            NaN        NaN
# 305                         NaN              NaN            NaN  71.863934
# 306                         NaN              NaN            NaN        NaN
#
#       Min Temp   Max Temp  Avg Pressure  Wind Speed  Precipitation       Fog
# 0    25.444262  43.968852    816.267213    5.247541       1.925738  0.737705
# 1    43.640984  62.755738    267.388525    2.103279       0.143770  0.344262
# 3    55.801639  82.947541    999.900000   10.960656       0.000000  0.000000
# 4    25.162295  48.598361    857.677049    2.834426       0.044262  0.000000
# 5          NaN        NaN           NaN         NaN            NaN       NaN
# ..         ...        ...           ...         ...            ...       ...
# 301        NaN        NaN           NaN         NaN            NaN       NaN
# 303        NaN        NaN           NaN         NaN            NaN       NaN
# 304        NaN        NaN           NaN         NaN            NaN       NaN
# 305  64.203279  81.411475    999.900000    5.608197      21.384754  0.475410
# 306        NaN        NaN           NaN         NaN            NaN       NaN
#
# [186 rows x 63 columns]

# %%
df.to_csv('data/final_data.csv', index=False)
